# %%
from PIL import Image

# %%
# !isfile ~/Downloads/seg_map_state.png
# Out:
# zsh:1: command not found: isfile

# %%
im = Image.open("/Users/nuowenlei/Downloads/seg_state (1).png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1999x1999 at 0x7FFE30F1AED0>

# %%
import numpy as np

# %%
arr = np.array(im)

# %%
arr.shape
# Out:
# (1999, 1999, 3)

# %%
import matplotlib.pyplot as plt

plt.imshow(arr[590:1310, 175:1550])

# %%
cropped_arr = arr[590:1310, 175:1550]

# %%
np.unique(cropped_arr.sum(axis = -1)).shape
# Out:
# (64,)
